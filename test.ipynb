# %% [markdown]
# # Markdown Tutorial (Titel)
# ## Basics
# Ich möchte *kursiv*, **fett** oder ***beides*** schreiben [link](kour.io)
# ## Aufzählung
# ### Unnummeriert
# - und eine
# - Aufzählen
# ### Nummeriert
# 1. Eins
# 2. Zwei
# 3. Drei
# ### Formel
# lineare Funktionen:
# $$f(x) = m * x + b$$
# Geht auch direkt im Fliesstext: $a^2 + b^2 = c^2$
# Brüche in der Mathe wie $\frac{\pi^2}{6}$ sind besser als Beinbrüche

# %% [markdown]
# Lineare Funktion:
# $$f(x) = m * x + b$$
# $a^2 + b^2 = c^2$
# $\pi$

# %%
x = 1

while x <= 100:
    if x % 3 == 0 and x % 5 == 0:
        print("FizzBuzz")
    elif x % 3 == 0:
        print("Fizz")
    elif x % 5 == 0:
        print("Buzz")
    else:
        print(x)
        
    x += 1
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %%
import math
 
a = 20
b = 0
 
for k in range(a):
    b += 1 / math.factorial(k)
 
print(b)
# Out:
# 2.7182818284590455
